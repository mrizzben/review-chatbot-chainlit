# %%
import pandas as pd
import os

os.chdir('..')

# %%
df = pd.read_csv("./data/raw/SPOTIFY_REVIEWS.csv")

# %%
df.sample(30)
# Out:
#          Unnamed: 0                             review_id  \
# 3154098     3154098  caf4d6e8-325d-4cda-99b5-2564e7ca1b08
# 1239163     1239163  51fdd33e-08fb-45ec-9d9f-894c07d9c083
# 2034873     2034873  fcb3f57d-c6ed-43b5-bc98-14aa48c76436
# 465558       465558  5db9266e-e979-4ecc-b01f-5c62df2f4781
# 992900       992900  f321bb31-9c37-4f9b-bfdb-a7c7cf237b28
# 1696285     1696285  f98996f1-e7c2-4fee-9e16-61e67708123d
# 1011847     1011847  2a82c321-5db0-4824-9ab6-84f300b57d41
# 2006372     2006372  7302b146-9509-4aee-a958-0432e6cc90ae
# 147734       147734  0fa366fa-84b3-4762-8690-b44e4f72ff3c
# 230596       230596  50cd21e7-25b3-44bd-ba14-4dcb37dab141
# 373453       373453  c8c691a0-6ee8-4b18-801f-e01310a734f9
# 1919934     1919934  10a71e89-e53e-463a-bc35-dad6b39dd05f
# 1503852     1503852  e40a6406-c5be-4036-b33b-b1e23c39b844
# 2163193     2163193  82211bc5-7688-4c55-b291-16bb7299d108
# 76547         76547  745080bf-d82d-4f37-83de-01648139628b
# ...

# %%
df['review_text']
# Out:
# 0                                           Use it every day
# 1          I enjoy the awesome UI of this app, and it has...
# 2                        Love it! Especially the new design!
# 3                      Awesome UI, best music app out there!
# 4          As a professional Android developer I'm glad t...
#                                  ...
# 3377418    Does not work, always says no internet but U t...
# 3377419                                              Goodjob
# 3377420                    The blues always pull me through.
# 3377421     awesome but you can't choose your song sometimes
# 3377422                 Ads again again n again ...worst app
# Name: review_text, Length: 3377423, dtype: object

# %% [markdown]
# I think we can just focus on review text, not too worry too much about ratings and other IDs
